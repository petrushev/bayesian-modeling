# %% [markdown]
# # Random walks $R_t$ factor with Student-t likelihood of daily cases with adjusted measurement for weekdays

# %%
from datetime import date, timedelta
import locale
import calendar

import pandas as pd
import numpy as np
import pymc3 as pm
import arviz as az
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
import theano.tensor as tt

# %%
plt.style.use('seaborn-whitegrid')
plt.rcParams.update({'figure.figsize': [10, 5], 'figure.dpi': 95})

# %%
data = pd.read_csv('https://raw.githubusercontent.com/treker-mk/data/master/csv/stats.csv')
data = data.assign(date = pd.to_datetime(data.date))
data = data[data.date.dt.date >= date(2020, 3, 20)]
data.tail(8)[['date', 'cases.confirmed']]
# Out:
#           date  cases.confirmed
# 676 2021-12-31            435.0
# 677 2022-01-01            246.0
# 678 2022-01-02            242.0
# 679 2022-01-03           1197.0
# 680 2022-01-04           1375.0
# 681 2022-01-05           1725.0
# 682 2022-01-06           1171.0
# 683 2022-01-07            632.0

# %%
plt.scatter(data.date, data['cases.confirmed'], marker='.')
plt.gca().set(ylim=(-1, None), xlim=(data.date.min(), None))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b'))

# %% [markdown]
# ### Model

# %% [markdown]
# We model the new daily cases as simple reproduction with a Student's t likelihood:
#
# $$ \text{observed}_t \sim t_\nu(\mu_t, \alpha) $$

# %% [markdown]
# The daily average is censored by a factor $ w_d $  depending on the day of week:
#
# $$ \mu_t = w_{d_t} \overline \mu_t $$

# %% [markdown]
# where the true average is simply a multiple of the day before:
#
# $$ \overline \mu_{t+1} = R_t  \overline \mu_t $$

# %% [markdown]
# which can be rewriten as (note: $ \overline \mu_0 = 1$):
#
# $$ \log \overline \mu_{t+1} = \log \overline \mu_{t} + \log R_t $$

# %% [markdown]
# $$ \log \overline \mu_t = \log \overline  \mu_0 \sum_{\tau=1}^t \log R_{\tau} $$

# %% [markdown]
# We will model the $R_t$ as autoregressive AR1 process in the log scale (the factor is always positive):
#
# $$ \log R_t \sim \text{AR}_1 (\varphi, 0.01^2) $$

# %% [markdown]
# where the autocorrelation can be modeles with a Beta prior:
#
# $$ \dfrac{\varphi + 1}{2} \sim \text{Beta}(5, 1) $$

# %% [markdown]
# The censoring should average out on a weekly level, i.e.:
#
# $$ \sum w_d = 7 $$

# %% [markdown]
# therefore, we can use a Dirichlet prior:
#
# $$ \frac{\mathbf w }{7} \sim \text{Dirichlet}(\mathbf 1) $$

# %% [markdown]
# Finally, for the scale parameter we will use log-normal prior, to avoid low values that might introduce an unidentifiability issues with respect to $\sigma$:
#
# $$ \alpha \sim \text{Log-Normal}(\log 20, 1) $$

# %% [markdown]
# and for the degrees of freedom a standardized default prior:
#
# $$ \nu \sim \text{Gamma}(2, 0.1) $$

# %%
mu0 = data['cases.confirmed'].values[0]

with pm.Model() as model6:
    N = data.shape[0]
    weekday_i = data.date.dt.weekday.values

    _phi = pm.Beta('_phi', 5, 1)
    phi = pm.Deterministic('phi', 2 * _phi - 1)

    logR = pm.AR1('logR', k=phi, tau_e=1e4, shape=N+10)

    R = pm.Deterministic('R', tt.exp(logR))
    mu_true = pm.Deterministic('mu_true', mu0 * tt.exp(tt.cumsum(logR)))

    # weekday censoring
    _w = pm.Dirichlet('_w', a=np.ones(7), shape=7, testval=np.ones(7)/7)
    w = pm.Deterministic('w', 7*_w)

    mu_observed = pm.Deterministic('mu_observed', mu_true[:N] * w[weekday_i])

    alpha = pm.Lognormal('alpha', np.log(20), 1)
    nu = pm.Gamma('nu', 2, 0.1)
    pm.StudentT(
        'obs', mu=mu_observed, sigma=alpha, nu=nu,
        observed=data['cases.confirmed'].values)

    trace6 = pm.sample(8000, tune=4000, chains=2, cores=2)
# Out:
# /tmp/ipykernel_82/4267560365.py:27: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace6 = pm.sample(8000, tune=4000, chains=2, cores=2)
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [nu, alpha, _w, logR, _phi]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='24000' class='' max='24000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [24000/24000 31:24<00:00 Sampling 2 chains, 285 divergences]
#     </div>
# Sampling 2 chains for 4_000 tune and 8_000 draw iterations (8_000 + 16_000 draws total) took 1887 seconds.
# There were 163 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 122 divergences after tuning. Increase `target_accept` or reparameterize.
# The number of effective samples is smaller than 10% for some parameters.

# %%
az.plot_forest(trace6, var_names=['w'], hdi_prob=0.95, figsize=(8, 4))
plt.gca().set(title='weekday measurement impact',
              yticklabels=(tuple(calendar.day_name)*2)[13:6:-1])
plt.axvline(1, color='gray')
None
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /usr/local/lib/python3.10/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %%
ax = az.plot_trace(trace6, var_names=['phi', 'alpha', 'nu'])
ax[0, 0].get_figure().tight_layout()
None
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /usr/local/lib/python3.10/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# Got error No model on context stack. trying to find log_likelihood in translation.

# %%
dates = pd.date_range(data['date'].min(), data['date'].max() + timedelta(days=10)).to_series()

# %%
locale.setlocale(6, 'en_US.UTF-8')

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 9), sharex=True)
tmp = az.hdi(trace6['R'] , hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
tmp = tmp.assign(mean_ = trace6['R'].mean(axis=0))
tmp.mean_.plot(ax=ax1, label='')
ax1.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, color='C0', label='95% hdi')

tmp = az.hdi(trace6['R'] , hdi_prob=0.5)
tmp = pd.DataFrame(tmp, index=dates)
ax1.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.6, color='C0', label='50% hdi')

ax1.axhline(1, linestyle='--', linewidth=1, color='k')
ax1.set(title='$R_t$', xlabel='date', ylim=(0.7, 1.3))
ax1.legend()

# workday 6
tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, :5].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
ax2.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, label='workday, 95% hdi', color='C0')

# weekend 6
tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, 5:].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
ax2.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, label='weekend', color='C2')

ax2.plot(data['date'], data['cases.confirmed'],
         color='k', label='observed', marker='.', linewidth=0)
ax2.set(title='new daily cases', xlabel='date', ylim=(-1, None),
        xlim=(date(2021, 4, 1), dates.max()))

ax2.legend(loc='upper left')
ax2.xaxis.set_major_locator(mdates.MonthLocator())
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

fig.tight_layout()
fig.savefig('mk_daily_R_en.png')
None
# Out:
# /tmp/ipykernel_82/1992555332.py:4: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['R'] , hdi_prob=0.95)
# /tmp/ipykernel_82/1992555332.py:10: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['R'] , hdi_prob=0.5)
# /tmp/ipykernel_82/1992555332.py:19: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, :5].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
# /tmp/ipykernel_82/1992555332.py:24: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, 5:].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)

# %%
locale.setlocale(6, 'mk_MK.UTF-8')

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 9), sharex=True)
tmp = az.hdi(trace6['R'] , hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
tmp = tmp.assign(mean_ = trace6['R'].mean(axis=0))
tmp.mean_.plot(ax=ax1, label='')
ax1.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, color='C0', label='95% hdi')

tmp = az.hdi(trace6['R'] , hdi_prob=0.5)
tmp = pd.DataFrame(tmp, index=dates)
ax1.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.6, color='C0', label='50% hdi')

ax1.axhline(1, linestyle='--', linewidth=1, color='k')
ax1.axvspan(data['date'].iloc[-1], dates.iloc[-1], color='C1', alpha=.2, label='прогноза')
ax1.set(title='$R_t$', xlabel='датум', ylim=(0.85, 1.15))
ax1.legend()

tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, :5].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
ax2.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, label='работен ден, 95% hdi', color='C0')

tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, 5:].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
ax2.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, label='викенд', color='C2')

ax2.plot(data['date'], data['cases.confirmed'],
         color='k', label='регистрирани', marker='.', linewidth=0)
ax2.set(title='нови потврдени случаи, дневно', xlabel='датум', ylim=(-1, 2000),
        xlim=(date(2021, 8, 29), None))
ax2.axvspan(data['date'].iloc[-1], dates.iloc[-1], color='C1', alpha=.2)

ax2.xaxis.set_major_locator(mdates.MonthLocator())
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax2.legend()

fig.tight_layout()
fig.savefig('mk_daily_R.png')
None
# Out:
# /tmp/ipykernel_82/4061460113.py:4: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['R'] , hdi_prob=0.95)
# /tmp/ipykernel_82/4061460113.py:10: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['R'] , hdi_prob=0.5)
# /tmp/ipykernel_82/4061460113.py:19: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, :5].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
# /tmp/ipykernel_82/4061460113.py:23: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, 5:].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)

# %% [markdown]
# ---

# %%
locale.setlocale(6, 'mk_MK.UTF-8')

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 9), sharex=True)
tmp = az.hdi(trace6['R'] , hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
tmp = tmp.assign(mean_ = trace6['R'].mean(axis=0))
tmp.mean_.plot(ax=ax1, label='')
ax1.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, color='C0', label='95% hdi')

tmp = az.hdi(trace6['R'] , hdi_prob=0.5)
tmp = pd.DataFrame(tmp, index=dates)
ax1.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.6, color='C0', label='50% hdi')

ax1.axhline(1, linestyle='--', linewidth=1, color='k')
ax1.set(title='$R_t$', xlabel='датум', ylim=(0.85, 1.35))
ax1.legend()

tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, :5].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
ax2.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, label='работен ден, 95% hdi', color='C0')

tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, 5:].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
tmp = pd.DataFrame(tmp, index=dates)
ax2.fill_between(tmp.index, tmp[0].values, tmp[1].values, alpha=.4, label='викенд', color='C2')

ax2.plot(data['date'], data['cases.confirmed'],
         color='k', label='регистрирани', marker='.', linewidth=0)
ax2.set(title='нови потврдени случаи, дневно', xlabel='датум', ylim=(-1, 850),
        xlim=(date(2021, 2, 1), None))

ax2.legend(loc='upper left')
ax2.xaxis.set_major_locator(mdates.MonthLocator())
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

fig.tight_layout()
None
# Out:
# /tmp/ipykernel_82/1427804421.py:4: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['R'] , hdi_prob=0.95)
# /tmp/ipykernel_82/1427804421.py:10: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['R'] , hdi_prob=0.5)
# /tmp/ipykernel_82/1427804421.py:18: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, :5].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
# /tmp/ipykernel_82/1427804421.py:22: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   tmp = az.hdi(trace6['mu_true'] * trace6['w'][:, 5:].mean(axis=1).reshape(-1, 1), hdi_prob=0.95)
